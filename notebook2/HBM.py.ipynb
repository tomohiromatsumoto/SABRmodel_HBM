# %%
sum = 0
for x in [1,2,3,4]:
    sum = sum + x
sum
# Out:
# 10

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

num_mc = 100
N        = 1000 #分割回数

y_init = 10 
t_init = 0
x_init = 10
t_end  = 1

dt   = t_end  / N
dW1   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))
dW2   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))

#t    = np.arange(t_init, t_end, dt)
y    = np.zeros(N)
q    = np.zeros(N)
y[0] = y_init
q[0] = q_init

for j in range(num_mc):
    for i in range(1, N):
        y[i] = y[i-1] +y[i-1] * dt * dW1
        q[i] = q[i-1] +y[i-1] * dt * dW2
        sum = 0
        for x in [q[N-1]]:
            sum = sum + x
            sum  
        
    plt.plot(t, x)

plt.show()
# Out:
# /Users/matsumototomohiro/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:25: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-1afcc67c6f6a> in <module>()
#      23 for j in range(num_mc):
#      24     for i in range(1, N):
# ---> 25         y[i] = y[i-1] +y[i-1] * dt * dW1
#      26         q[i] = q[i-1] +y[i-1] * dt * dW2
#      27         sum = 0
#
# TypeError: unsupported operand type(s) for *: 'float' and 'function'

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd



num_sims = 1 #試行回数
num_mc = 100
N        = 11 #分割回数

y_init = 10 
t_init = 0
q_init = 10
t_end  = 11

#c_theta = 0.9
#c_mu    = 0.1
c_sig = 0.4

#def mu(y, t): 
    #return c_theta * (c_mu - y)
        
def sig(y, t): 
    return c_sig

#np.random.normal = c
#np.random.normal = d
dt   = float(t_end - t_init) / N
dW1   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))
dW2   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))

t    = np.arange(t_init, t_end, dt)
y    = np.zeros(N)
q    = np.zeros(N)
y[0] = y_init
q[0] = q_init

for j in range(num_mc):
   
 for i in range(num_sims):
    for i in range(1, N):
        #a = mu(y[i-1], (i-1) * dt)
        b = sig(y[i-1], (i-1) * dt)
        y[i] = y[i-1] +y[i-1]*b * dW1(dt)
        q[i] = q[i-1] +y[i-1]*b * dW2(dt)
        
        #print("①",y[i])  #y[i]は満期での値を表している
    #m = y[j]
    def f(j):
        return j/2
    def sigma(func, frm, to):
        result = 0 #答えの受け皿
        for k in range (frm, to+1):
            result += func(k)
            #ここで関数を呼び出す。ちなみにここではk=x
        #df = pd.DataFrame({'C1': [y[1],y[9]],})
        #df
    
    
        #print("各パスの満期での値",q[N-1])
        
        sum = 0
    for x in [q[N-1]]:
        sum = sum + x
        sum 
    #print("合計値/試行回数",sum/num_mc )
    
        #print("結果",result)
    sigma(f,1,2)
        
    #print(sum/num_mc-1)
        
    plt.plot(t, q)

plt.show()



#print(y[9])
#print("price",y[3])
#print("price",y[1])

#df = pd.DataFrame({'C1': [y[1], y[2], y[3],y[4],y[5],y[6],y[7],y[8],y[9]],})
#df
#y[i]は最後のpathでのi分割したときの値を出している

# %%
print("合計値/試行回数",sum/num_mc )

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd



num_sims = 1 #試行回数
num_mc = 10
N        = 11 #分割回数

y_init = 10 
t_init = 0
q_init = 10
t_end  = 11

#c_theta = 0.9
#c_mu    = 0.1
c_sig = 0.4

#def mu(y, t): 
    #return c_theta * (c_mu - y)
        
def sig(y, t): 
    return c_sig

#np.random.normal = c
#np.random.normal = d
dt   = float(t_end - t_init) / N
dW1   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))
dW2   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))

t    = np.arange(t_init, t_end, dt)
y    = np.zeros(N)
q    = np.zeros(N)
y[0] = y_init
q[0] = q_init


for j in range(num_mc):
   
 for i in range(num_sims):
    for i in range(1, N):
        #a = mu(y[i-1], (i-1) * dt)
        b = sig(y[i-1], (i-1) * dt)
        y[i] = y[i-1] +y[i-1]*b * dW1(dt)
        q[i] = q[i-1] +y[i-1]*b * dW2(dt)
        
        #print("①",y[i])  #y[i]は満期での値を表している
    #m = y[j]
    def f(j):
        return j/2
    def sigma(func, frm, to):
        result = 0 #答えの受け皿
        for k in range (frm, to+1):
            result += func(k)
            #ここで関数を呼び出す。ちなみにここではk=x
        #df = pd.DataFrame({'C1': [y[1],y[9]],})
        #df
    
    
        #print("各パスの満期での値",q[N-1])
        
        sum = 0
    for x in [q[N-1]]:
        sum = sum + x
        sum 
    #print("合計値/試行回数",sum/num_mc )
    
        #print("結果",result)
    sigma(f,1,2)
        
    #print(sum/num_mc-1)
        
    plt.plot(t, q)

plt.show()



#print(y[9])
#print("price",y[3])
#print("price",y[1])

#df = pd.DataFrame({'C1': [y[1], y[2], y[3],y[4],y[5],y[6],y[7],y[8],y[9]],})
#df
#y[i]は最後のpathでのi分割したときの値を出している

# %%
print("合計値/試行回数",sum/num_mc )
# Out:
# 合計値/試行回数 11.0117335903

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd



num_sims = 1 #試行回数
num_mc = 100
N        = 11 #分割回数

y_init = 10 
t_init = 0
q_init = 10
t_end  = 11

#c_theta = 0.9
#c_mu    = 0.1
#c_sig = 0.4

#def mu(y, t): 
    #return c_theta * (c_mu - y)
        
#def sig(y, t): 
    #return c_sig
#for N in range(101,200):
    
#np.random.normal = c
#np.random.normal = d
dt   = float(t_end - t_init) / N
dW1   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))
dW2   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))

t    = np.arange(t_init, t_end, dt)
y    = np.zeros(N)
q    = np.zeros(N)
y[0] = y_init
q[0] = q_init

 for N in range(11,20):
    for j in range(num_mc):
            for i in range(num_sims):
                for i in range(1, N):
                    #a = mu(y[i-1], (i-1) * dt)
                       b = sig(y[i-1], (i-1) * dt)
                        y[i] = y[i-1] +y[i-1]*b * dW1(dt)
                        q[i] = q[i-1] +y[i-1]*b * dW2(dt)
    #print("①",y[i])  #y[i]は満期での値を表している
        #m = y[j]
    def f(j):
    return j/2
          def sigma(func, frm, to):
                result = 0 #答えの受け皿
                for k in range (frm, to+1):
                result += func(k)
            #ここで関数を呼び出す。ちなみにここではk=x
             #df = pd.DataFrame({'C1': [y[1],y[9]],})
            #df
            #print("各パスの満期での値",q[N-1])
        sum = 0
        for x in [q[N-1]]:
            sum = sum + x
            sum 
    #print("合計値/試行回数",sum/num_mc )
    
        #print("結果",result)
        sigma(f,1,2)
        
plt.plot(N, sum/num_mc)

plt.show()



#print(y[9])
#print("price",y[3])
#print("price",y[1])

#df = pd.DataFrame({'C1': [y[1], y[2], y[3],y[4],y[5],y[6],y[7],y[8],y[9]],})
#df
#y[i]は最後のpathでのi分割したときの値を出している
# Out:
#   File "<ipython-input-22-967b6b708b00>", line 39
#     for N in range(11,20):
#     ^
# IndentationError: unexpected indent

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd



num_sims = 1 #試行回数
num_mc = 100
N        = 11 #分割回数
y_init = 10 
t_init = 0
q_init = 10
t_end  = 11
c_sig = 0.4


def sig(y, t): 
    return c_sig

#for N in range(101,200):
    

    dt   = float(t_end - t_init) / N
    dW1   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))
    dW2   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))

    t    = np.arange(t_init, t_end, dt)
    y    = np.zeros(N)
    q    = np.zeros(N)
    y[0] = y_init
    q[0] = q_init

 for N in range(11,20):
       for j in range(num_mc):
                 for i in range(num_sims):
                 for i in range(1, N):
                        b = sig(y[i-1], (i-1) * dt)
                        y[i] = y[i-1] +y[i-1]*b * dW1(dt)
                        q[i] = q[i-1] +y[i-1]*b * dW2(dt)
   
           def f(j):
           return j/2
           def sigma(func, frm, to):
                 result = 0 #答えの受け皿
                    for k in range (frm, to+1):
                    result += func(k)
           
        sum = 0
        for x in [q[N-1]]:
            sum = sum + x
            sum 
 
    
       
        sigma(f,1,2)
        
plt.plot(N, sum/num_mc)

plt.show()
# Out:
#   File "<ipython-input-31-6a873628f590>", line 33
#     for N in range(11,20):
#                           ^
# IndentationError: unindent does not match any outer indentation level

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd



num_sims = 1 #試行回数
num_mc = 100
N        = 1001 #分割回数

y_init = 10 
t_init = 0
q_init = 10
t_end  = 11

#c_theta = 0.9
#c_mu    = 0.1fsum
#c_sig = 0.4

#def mu(y, t): 
    #return c_theta * (c_mu - y)
        
#def sig(y, t): 
    #return c_sig

dt   = float(t_end - t_init) / N
dW1   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))
dW2   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))

t    = np.arange(t_init, t_end, dt)
y    = np.zeros(N)
q    = np.zeros(N)
y[0] = y_init
q[0] = q_init

for j in range(num_mc):
   
 #for i in range(num_sims):
    for i in range(1, N):
        #a = mu(y[i-1], (i-1) * dt)
        b = sig(y[i-1], (i-1) * dt)
        y[i] = y[i-1] +y[i-1]*b * dW1(dt)
        q[i] = q[i-1] +y[i-1]*b * dW2(dt)
        
        #print("①",y[i])  #y[i]は満期での値を表している
    #m = y[j]
    def f(j):
        return j/2
    def sigma(func, frm, to):
        result = 0 #答えの受け皿
        for k in range (frm, to+1):
            result += func(k)
            #ここで関数を呼び出す。ちなみにここではk=x
        #df = pd.DataFrame({'C1': [y[1],y[9]],})
        #df
    
    
        #print("各パスの満期での値",q[N-1])
        
        sum = 0
    for x in [q[N-1]]:
        sum = sum + x
        sum 
        
    plt.plot(t, q)

plt.show()

# %%
print("合計値/試行回数",sum/num_mc )
# Out:
# 合計値/試行回数 10.2960966706

# %%
plt.plot(num_mc, sum/num_mc, '.')

# %%
U = N
P = sum/num_mc

plt.plot(N, P, 'o')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-8b4893cafb15> in <module>()
#       1 U = N
# ----> 2 P = sum/num_mc
#       3
#       4 plt.plot(N, P, 'o')
#       5 plt.show()
#
# TypeError: unsupported operand type(s) for /: 'builtin_function_or_method' and 'int'

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

num_sims = 1 #試行回数
num_mc = 10
N        = 11#分割回数
y_init = 10 
t_init = 0
q_init = 10
t_end  = 11
c_sig = 0.3

def sig(y, t): 
    return c_sig # Ends here??? Nothing done!!! 

dt   = float(t_end - t_init) / N
dW1   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))
dW2   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))
t    = np.arange(t_init, t_end, dt)
y    = np.zeros(N)
q    = np.zeros(N)
y[0] = y_init
q[0] = q_init

for num_mc in range(1,20):
    for j in range(num_mc):
        for i in range(num_sims):
            for i in range(1, N):
                b = sig(y[i-1], (i-1) * dt)
                y[i] = y[i-1] +y[i-1]*b * dW1(dt)
                q[i] = q[i-1] +y[i-1]*b * dW2(dt)
                def f(j):
                    return j/2
                def sigma(func, frm, to):
                    result = 0 #答えの受け皿
                    for k in range (frm, to+1):
                        result += func(k)
                        sum =0
                        for x in [q[N-1]]:
                            sum = sum + x
                            sum 
                            #sigma(f,1,2)
    plt.plot(sum/num_mc, num_mc, '.')

plt.show()

# %%
print("合計値/試行回数",sum/num_mc )
# Out:
# 合計値/試行回数 54.2129804161

# %%
ls
# Out:
# HBM.py.ipynb                numerical result .py.ipynb
# labo.py.ipynb               prac1.ipynb
# labo2.py.ipynb              result.py.ipynb
# labo3.py.ipynb

# %%
ls ../src/
# Out:
# BM.py                        Option_2017_1_10.py.ipynb
# BM.py.ipynb                  __pycache__/
# BM_test2016_12_20.py         util.py
# BM_test_2016_12_20.py.ipynb

# %%
pwd
# Out:
# '/Users/matsumototomohiro/Dropbox/Research/SABRmodel_HBM/notebook2'

# %%
import importlib

import sys
#  Look inside the folder source.   ../ means "a directory above" 
sys.path.append("../src/")

# %%
import util as uti 
importlib.reload(uti)
# Out:
# <module 'util' from '../src/util.py'>

# %%
hoge = uti.print_time()

# %%
print(hoge)
# Out:
# 2017_02_10_15_19_32

# %%
pwd
# Out:
# '/Users/matsumototomohiro/Dropbox/Research/SABRmodel_HBM/notebook2'

# %%
import importlib

import sys
#  Look inside the folder source.   ../ means "a directory above" 
sys.path.append("../src/")

# %%
print(sum/num_mc)
# Out:
# 0.372606177325

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

num_sims = 1 #試行回数
num_mc = 10
N        = 11#分割回数
y_init = 10 
t_init = 0
x_init = 10
t_end  = 10
c_sig = 0.3

def sig(y, t): 
    return c_sig # Ends here??? Nothing done!!! 

dt   =  (t_end )/ N
dW1   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))
dW2   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))
t    = np.arange(t_init, t_end, dt)
y    = np.zeros(N)
x    = np.zeros(N)
y[0] = y_init
x[0] = x_init

for num_mc in range(1,20):
    for i in range(num_sims):
            for i in range(1, N):
                y[i] = y[i-1] +y[i-1]*sig(y[i-1], (i-1) * dt) * dW1(dt)
                x[i] = x[i-1] +y[i-1]*sig(y[i-1], (i-1) * dt) * dW2(dt)
                def f(j):
                    return j/2
                def sigma(func, frm, to):
                    result = 0 #答えの受け皿
                    for k in range (frm, to+1):
                        result += func(k)
                        sum =0
                        for q in [x[N-1]]:
                            sum = sum + q
                            sum 
                            #sigma(f,1,2)
    plt.plot(sum/num_mc, num_mc, '.')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import matplotlib as mpl


num_sims = 1 #試行回数
num_mc = 10
#N        = 11#分割回数
y_init = 10 
t_init = 0
q_init = 10
t_end  = 11
c_sig = 0.3

for N in range(1,40):
    def sig(y, t):
        return c_sig
    dt   = float(t_end - t_init) / N
    dW1   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))
    dW2   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))
    t    = np.arange(t_init, t_end, dt)
    y    = np.zeros(N)
    q    = np.zeros(N)
    y[0] = y_init
    q[0] = q_init
    #for N in range(1,12):
    for j in range(num_mc):
        #for i in range(num_sims):
            for i in range(1, N):
                b = sig(y[i-1], (i-1) * dt)
                y[i] = y[i-1] +y[i-1]*b * dW1(dt)
                q[i] = q[i-1] +y[i-1]*b * dW2(dt)
                def f(j):
                    return j/2
                def sigma(func, frm, to):
                    result = 0 #答えの受け皿
                    for k in range (frm, to+1):
                        result += func(k)
                        sum 
                        for x in [q[N-1]]:
                            sum = sum + x
                            sum
            plt.plot(N, sum/num_mc, '.')
    plt.show()                            
                            
#plt.plot(N, sum)

#plt.show()
