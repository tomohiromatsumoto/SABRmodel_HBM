# %%
sum = 0
for x in [1,2,3,4]:
    sum = sum + x
sum
# Out:
# 10

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd



num_sims = 1 #試行回数
num_mc = 2
N        = 11 #分割回数

y_init = 10 
t_init = 0
q_init = 10
t_end  = 11

#c_theta = 0.9
#c_mu    = 0.1
c_sig = 0.4

#def mu(y, t): 
    #return c_theta * (c_mu - y)
        
def sig(y, t): 
    return c_sig

#np.random.normal = c
#np.random.normal = d
dt   = float(t_end - t_init) / N
dW1   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))
dW2   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))

t    = np.arange(t_init, t_end, dt)
y    = np.zeros(N)
q    = np.zeros(N)
y[0] = y_init
q[0] = q_init


for j in range(num_mc):
   
 for i in range(num_sims):
    for i in range(1, N):
        #a = mu(y[i-1], (i-1) * dt)
        b = sig(y[i-1], (i-1) * dt)
        y[i] = y[i-1] +y[i-1]*b * dW1(dt)
        q[i] = q[i-1] +y[i-1]*b * dW2(dt)
        
        #print("①",y[i])  #y[i]は満期での値を表している
    #m = y[j]
    def f(j):
        return j/2
    def sigma(func, frm, to):
        result = 0 #答えの受け皿
        for k in range (frm, to+1):
            result += func(k)
            #ここで関数を呼び出す。ちなみにここではk=x
        #df = pd.DataFrame({'C1': [y[1],y[9]],})
        #df
    
    
        #print("各パスの満期での値",q[N-1])
        
        sum = 0
    for x in [q[N-1]]:
        sum = sum + x
        sum 
    #print("合計値/試行回数",sum/num_mc )
    
        #print("結果",result)
    sigma(f,1,2)
        
    #print(sum/num_mc-1)
        
    plt.plot(t, q)

plt.show()



#print(y[9])
#print("price",y[3])
#print("price",y[1])

#df = pd.DataFrame({'C1': [y[1], y[2], y[3],y[4],y[5],y[6],y[7],y[8],y[9]],})
#df
#y[i]は最後のpathでのi分割したときの値を出している

# %%
print("合計値/試行回数",sum/num_mc )
# Out:
# 合計値/試行回数 3.9118753401

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd



num_sims = 1 #試行回数
num_mc = 10
N        = 11 #分割回数

y_init = 10 
t_init = 0
q_init = 10
t_end  = 11

#c_theta = 0.9
#c_mu    = 0.1
c_sig = 0.4

#def mu(y, t): 
    #return c_theta * (c_mu - y)
        
#def sig(y, t): 
    #return c_sig

#np.random.normal = c
#np.random.normal = d
dt   = float(t_end - t_init) / N
dW1   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))
dW2   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))

t    = np.arange(t_init, t_end, dt)
y    = np.zeros(N)
q    = np.zeros(N)
y[0] = y_init
q[0] = q_init

for j in range(num_mc):
   
 for i in range(num_sims):
    for i in range(1, N):
        #a = mu(y[i-1], (i-1) * dt)
        #b = sig(y[i-1], (i-1) * dt)
        y[i] = y[i-1] +y[i-1]* sig(y[i-1], (i-1) * dt)*dW1(dt)
        q[i] = q[i-1] +y[i-1]* sig(y[i-1], (i-1) * dt)*dW2(dt)
        
        #print("①",y[i])  #y[i]は満期での値を表している
    #m = y[j]
    def f(j):
        return j/2
    def sigma(func, frm, to):
        result = 0 #答えの受け皿
        for k in range (frm, to+1):
            result += func(k)
            #ここで関数を呼び出す。ちなみにここではk=x
        #df = pd.DataFrame({'C1': [y[1],y[9]],})
        #df
    
    
        #print("各パスの満期での値",q[N-1])
        
        sum = 0
    for x in [q[N-1]]:
        sum = sum + x
        sum 
    #print("合計値/試行回数",sum/num_mc )
    
        #print("結果",result)
    #sigma(f,1,2)
        
    #print(sum/num_mc-1)
        
    plt.plot(t, q)

plt.show()



#print(y[9])
#print("price",y[3])
#print("price",y[1])

#df = pd.DataFrame({'C1': [y[1], y[2], y[3],y[4],y[5],y[6],y[7],y[8],y[9]],})
#df
#y[i]は最後のpathでのi分割したときの値を出している

# %%
print("合計値/試行回数",sum/num_mc )
# Out:
# 合計値/試行回数 -2.44772008848

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import matplotlib as mpl


num_sims = 1 #試行回数
num_mc = 10
#N        = 11#分割回数
y_init = 10 
t_init = 0
q_init = 10
t_end  = 11
c_sig = 0.3

for N in range(1,40):
    def sig(y, t):
        return c_sig
    dt   = float(t_end - t_init) / N
    dW1   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))
    dW2   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))
    t    = np.arange(t_init, t_end, dt)
    y    = np.zeros(N)
    q    = np.zeros(N)
    y[0] = y_init
    q[0] = q_init
    #for N in range(1,12):
    for j in range(num_mc):
        for i in range(num_sims):
            for i in range(1, N):
                b = sig(y[i-1], (i-1) * dt)
                y[i] = y[i-1] +y[i-1]*b * dW1(dt)
                q[i] = q[i-1] +y[i-1]*b * dW2(dt)
                def f(j):
                    return j/2
                def sigma(func, frm, to):
                    result = 0 #答えの受け皿
                    for k in range (frm, to+1):
                        result += func(k)
                        sum 
                        for x in [q[N-1]]:
                            sum = sum + x
                            sum 
                            #sigma(f,1,2)
                            
                            
U = N
P = sum/num_mc

plt.plot(N, P, '.')
plt.show()
                            
#plt.plot(N, sum)

#plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import matplotlib as mpl


num_sims = 1 #試行回数
num_mc = 10
#N        = 11#分割回数
y_init = 10 
t_init = 0
q_init = 10
t_end  = 11
c_sig = 0.3

for N in range(1,40):
    def sig(y, t):
        return c_sig
    dt   = float(t_end - t_init) / N
    dW1   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))
    dW2   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))
    t    = np.arange(t_init, t_end, dt)
    y    = np.zeros(N)
    q    = np.zeros(N)
    y[0] = y_init
    q[0] = q_init
    #for N in range(1,12):
    for j in range(num_mc):
        for i in range(num_sims):
            for i in range(1, N):
                b = sig(y[i-1], (i-1) * dt)
                y[i] = y[i-1] +y[i-1]*b * dW1(dt)
                q[i] = q[i-1] +y[i-1]*b * dW2(dt)
                def f(j):
                    return j/2
                def sigma(func, frm, to):
                    result = 0 #答えの受け皿
                    for k in range (frm, to+1):
                        result += func(k)
                        sum 
                        for x in [q[N-1]]:
                            sum = sum + x
                            sum
    #hold(True);
    plt.plot(N, sum/num_mc, '.')
plt.show()                            
                            
#plt.plot(N, sum)

#plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import matplotlib as mpl


num_sims = 1 #試行回数
num_mc = 10
#N        = 11#分割回数
y_init = 10 
t_init = 0
q_init = 10
t_end  = 11
c_sig = 0.3

for N in range(1,40):
    def sig(y, t):
        return c_sig
    dt   = float(t_end - t_init) / N
    dW1   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))
    dW2   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))
    t    = np.arange(t_init, t_end, dt)
    y    = np.zeros(N)
    q    = np.zeros(N)
    y[0] = y_init
    q[0] = q_init
    #for N in range(1,12):
    for j in range(num_mc):
        #for i in range(num_sims):
            for i in range(1, N):
                b = sig(y[i-1], (i-1) * dt)
                y[i] = y[i-1] +y[i-1]*b * dW1(dt)
                q[i] = q[i-1] +y[i-1]*b * dW2(dt)
                def f(j):
                    return j/2
                def sigma(func, frm, to):
                    result = 0 #答えの受け皿
                    for k in range (frm, to+1):
                        result += func(k)
                        sum 
                        for x in [q[N-1]]:
                            sum = sum + x
                            sum
            plt.plot(N, sum/num_mc, '.')
    plt.show()                            
                            
#plt.plot(N, sum)

#plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import matplotlib as mpl


num_sims = 1 #試行回数
num_mc = 10
#N        = 11#分割回数
y_init = 10 
t_init = 0
q_init = 10
t_end  = 11
c_sig = 0.3

for N in range(1,40):
    def sig(y, t):
        return c_sig
    dt   = float(t_end - t_init) / N
    dW1   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))
    dW2   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))
    t    = np.arange(t_init, t_end, dt)
    y    = np.zeros(N)
    q    = np.zeros(N)
    y[0] = y_init
    q[0] = q_init
    #for N in range(1,12):
    for j in range(num_mc):
        for i in range(num_sims):
            for i in range(1, N):
                b = sig(y[i-1], (i-1) * dt)
                y[i] = y[i-1] +y[i-1]*b * dW1(dt)
                q[i] = q[i-1] +y[i-1]*b * dW2(dt)
                def f(j):
                    return j/2
                def sigma(func, frm, to):
                    result = 0 #答えの受け皿
                    for k in range (frm, to+1):
                        result += func(k)
                        sum 
                        for x in [q[N-1]]:
                            sum = sum + x
                            sum
            plt.plot(N, sum/num_mc, '.')
    plt.show()                            
                            
#plt.plot(N, sum)

#plt.show()

# %%
print("合計値/試行回数",sum/num_mc )
# Out:
# 合計値/試行回数 0.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd



def HyperbolicBM(N= 100,  t_end = 10,  y_init = 10, t_init = 0,  q_init = 10):

    #初期値
    ynow = y_init
    xnow = x_init
    tnow = t_init

    #ここでオイラー丸山
    dt = t_end/N

    #BMを生成
　　　　dW1   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))
　　　　dW2   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))

　　#HyperbolicBM
　　　　b = sig(y[i-1], (i-1) * dt)
　　　　y[i] = y[i-1] +y[i-1]*b * dW1(dt)
　　　　x[i] = q[i-1] +y[i-1]*b * dW2(dt)
# Out:
#   File "<ipython-input-2-c64235e78350>", line 18
#     dW1   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))
#       ^
# SyntaxError: invalid character in identifier

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

num_sims = 1 #試行回数
num_mc = 100
N        = 1001 #分割回数

y_init = 10 
t_init = 0
q_init = 10
t_end  = 11
c_sig = 0.4

#def mu(y, t): 
    #return c_theta * (c_mu - y)
        
def sig(y, t): 
    return c_sig

dt   = float(t_end - t_init) / N
dW1   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))
dW2   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))

t    = np.arange(t_init, t_end, dt)
y    = np.zeros(N)
q    = np.zeros(N)
y[0] = y_init
q[0] = q_init

for j in range(num_mc):
   
    for i in range(1, N):
        b = sig(y[i-1], (i-1) * dt)
        y[i] = y[i-1] +y[i-1]*b * dW1(dt)
        q[i] = q[i-1] +y[i-1]*b * dW2(dt)
        
        #print("①",y[i])  #y[i]は満期での値を表している
    #m = y[j]
    def f(j):
        return j/2
    def sigma(func, frm, to):
        result = 0 #答えの受け皿
        for k in range (frm, to+1):
            result += func(k)
            #ここで関数を呼び出す。ちなみにここではk=x
       
        #print("各パスの満期での値",q[N-1])
        
        sum = 0
    for x in [q[N-1]]:
        sum = sum + x
        sum  
        
    plt.plot(t, q)

plt.show()

# %%
print("合計値/試行回数",sum/num_mc )
# Out:
# 合計値/試行回数 18.2026383135

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


def HyperbolicBM(N= 10,  t_end = 10,  y_init = 10, t_init = 0,  q_init = 10):

    #初期値
    y[0] = y_init
    x[0] = x_init
    t[0] = t_init

    #ここでオイラー丸山
    dt = t_end/N

    #BMを生成
    dW1   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))
    dW2   = lambda dt: np.random.normal (loc = 0.0, scale = np.sqrt(dt))

    #HyperbolicBM　
    y[i] = y[i-1] +y[i-1] *  (dW1 * dt)
    x[i] = x[i-1] +y[i-1] *  (dW2 * dt)
    return x[N]

# %%
print (x)
# Out:
# -5.3307566179
