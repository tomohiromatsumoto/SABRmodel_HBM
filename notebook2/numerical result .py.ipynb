# %%
print('E[Xt]について')
np.exp(-909)*0+0.1*(1-np.exp(-909))
# Out:
# E[Xt]について
# 0.10000000000000001

# %%
print('V[Yt]について')
(0.16/1.8)*(1-np.exp(-2*0.9*1001))
# Out:
# V[Yt]について
# 0.088888888888888892

# %%
print('(σ/sqrt(2π))*e^((-(k-μ)^2)/2σ^2)+(μ-k)*1/2*Erfc(-x/sqrt(2))を計算する')
print('つまり(sqrt(V[Yt])/sqrt(2π))*e^((-(k-E[Xt])^2)/2*V[Yt])+(E[Xt]-k)*1/2*Erfc(-x/sqrt(2))')
print('ここでいうxは(-k＋μ)/σ')
(1/(np.sqrt(2*3.1416)))*np.sqrt(0.0888888)*np.exp(-(0.1*0.1)/2*0.0888888)+0.1*1/2*0.8025873
# Out:
# (σ/sqrt(2π))*e^((-(k-μ)^2)/2σ^2)+(μ-k)*1/2*Erfc(-x/sqrt(2))を計算する
# つまり(sqrt(V[Yt])/sqrt(2π))*e^((-(k-E[Xt])^2)/2*V[Yt])+(E[Xt]-k)*1/2*Erfc(-x/sqrt(2))
# ここでいうxは(-k＋μ)/σ
# 0.15901792315426733

# %%
0.1/(0.4*np.sqrt(2))
# Out:
# 0.17677669529663687

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd



num_sims = 1 #試行回数
num_mc = 100
N        = 101 #分割回数

y_init = 0 
t_init = 0
t_end  = 101

c_theta = 0.9
c_mu    = 0.1
c_sig = 0.4

def mu(y, t): 
    return c_theta * (c_mu - y)
        
def sig(y, t): 
    return c_sig

dt   = float(t_end - t_init) / N
dW   = lambda dt: np.random.normal(loc = 0.0, scale = np.sqrt(dt))

t    = np.arange(t_init, t_end, dt)
y    = np.zeros(N)
y[0] = y_init


for j in range(num_mc):
   
 for i in range(num_sims):
    for i in range(1, N):
        a = mu(y[i-1], (i-1) * dt)
        b = sig(y[i-1], (i-1) * dt)
        y[i] = y[i-1] + a * dt + b * dW(dt)
        
        #print("①",y[i])  #y[i]は満期での値を表している
    #m = y[j]
    def f(j):
        return j/2
    def sigma(func, frm, to):
        result = 0 #答えの受け皿
        for k in range (frm, to+1):
            result += func(k)
            #ここで関数を呼び出す。ちなみにここではk=x
        #df = pd.DataFrame({'C1': [y[1],y[9]],})
        #df
    
    
        print("各パスの満期での値",y[N-1])
        
        sum = 0
    for x in [y[N-1]]:
        sum = sum + x
        sum 
    print("合計値/試行回数",sum/num_mc )
    
        #print("結果",result)
    sigma(f,1,2)
        

    plt.plot(t, y)

plt.show()

#print(y[9])
#print("price",y[3])
#print("price",y[1])

#df = pd.DataFrame({'C1': [y[1], y[2], y[3],y[4],y[5],y[6],y[7],y[8],y[9]],})
#df
#y[i]は最後のpathでのi分割したときの値を出している
# Out:
# 合計値/試行回数 0.102319568595
# 各パスの満期での値 0.231956859543
# 合計値/試行回数 0.103125785722
# 各パスの満期での値 0.080621712623
# 合計値/試行回数 0.0989186524074
# 各パスの満期での値 -0.42071333143
# 合計値/試行回数 0.0988671504025
# 各パスの満期での値 -0.0051502004825
# 合計値/試行回数 0.101117349184
# 各パスの満期での値 0.225019878158
# 合計値/試行回数 0.104334642531
# 各パスの満期での値 0.321729334728
# 合計値/試行回数 0.103950672568
# 各パスの満期での値 -0.0383969963801
# 合計値/試行回数 0.102297798598
# 各パスの満期での値 -0.165287396935
# 合計値/試行回数 0.099655027214
# 各パスの満期での値 -0.264277138421
# 合計値/試行回数 0.107337305456
# 各パスの満期での値 0.768227824165
# 合計値/試行回数 0.107874830356
# 各パスの満期での値 0.0537524899849
# 合計値/試行回数 0.103216686198
# 各パスの満期での値 -0.465814415777
# 合計値/試行回数 0.102514288405
# 各パスの満期での値 -0.0702397792839
# 合計値/試行回数 0.105573859449
# 各パスの満期での値 0.30595710445
# 合計値/試行回数 0.101260289267
# 各パスの満期での値 -0.431357018221
# 合計値/試行回数 0.101572293118
# 各パスの満期での値 0.0312003850467
# 合計値/試行回数 0.107480773827
# 各パスの満期での値 0.590848070954
# 合計値/試行回数 0.105172157712
# 各パスの満期での値 -0.230861611499
# 合計値/試行回数 0.1068849441
# 各パスの満期での値 0.171278638758
# 合計値/試行回数 0.109817020359
# 各パスの満期での値 0.293207625949
# 合計値/試行回数 0.118614487008
# 各パスの満期での値 0.879746664856
# 合計値/試行回数 0.119528203533
# 各パスの満期での値 0.0913716525223
# 合計値/試行回数 0.112281300745
# 各パスの満期での値 -0.724690278796
# 合計値/試行回数 0.111027143806
# 各パスの満期での値 -0.125415693921
# 合計値/試行回数 0.111325544192
# 各パスの満期での値 0.0298400386488
# 合計値/試行回数 0.105966662309
# 各パスの満期での値 -0.535888188318
# 合計値/試行回数 0.106948914694
# 各パスの満期での値 0.098225238508
# 合計値/試行回数 0.10945253742
# 各パスの満期での値 0.250362272614
# 合計値/試行回数 0.110077671935
# 各パスの満期での値 0.062513451413
# 合計値/試行回数 0.117182801971
# 各パスの満期での値 0.710513003639
# 合計値/試行回数 0.121509872568
# 各パスの満期での値 0.432707059684
# 合計値/試行回数 0.117702119424
# 各パスの満期での値 -0.380775314403
# 合計値/試行回数 0.120690844595
# 各パスの満期での値 0.298872517161
# 合計値/試行回数 0.120137608484
# 各パスの満期での値 -0.0553236111555
# 合計値/試行回数 0.123121565333
# 各パスの満期での値 0.298395684904
# 合計値/試行回数 0.124254524492
# 各パスの満期での値 0.113295915908
# 合計値/試行回数 0.117380860904
# 各パスの満期での値 -0.687366358757
# 合計値/試行回数 0.116240582188
# 各パスの満期での値 -0.114027871643
# 合計値/試行回数 0.119347851701
# 各パスの満期での値 0.310726951355
# 合計値/試行回数 0.122266102508
# 各パスの満期での値 0.291825080662
# 合計値/試行回数 0.123940176001
# 各パスの満期での値 0.167407349296
# 合計値/試行回数 0.12141160103
# 各パスの満期での値 -0.252857497151
# 合計値/試行回数 0.118124828202
# 各パスの満期での値 -0.328677282725
# 合計値/試行回数 0.122277355693
# 各パスの満期での値 0.415252749095
# 合計値/試行回数 0.123169234862
# 各パスの満期での値 0.0891879169021
# 合計値/試行回数 0.11946588653
# 各パスの満期での値 -0.370334833252
# 合計値/試行回数 0.119310423457
# 各パスの満期での値 -0.0155463072525
# 合計値/試行回数 0.11563508982
# 各パスの満期での値 -0.367533363713
# 合計値/試行回数 0.12119246858
# 各パスの満期での値 0.555737876034
# 合計値/試行回数 0.119961702448
# 各パスの満期での値 -0.123076613256
# 合計値/試行回数 0.118317627935
# 各パスの満期での値 -0.164407451241
# 合計値/試行回数 0.114807071365
# 各パスの満期での値 -0.351055657083
# 合計値/試行回数 0.127691557749
# 各パスの満期での値 1.28844863846
# 合計値/試行回数 0.121252380428
# 各パスの満期での値 -0.643917732171
# 合計値/試行回数 0.126165824913
# 各パスの満期での値 0.491344448553
# 合計値/試行回数 0.124323743576
# 各パスの満期での値 -0.184208133689
# 合計値/試行回数 0.131818688781
# 各パスの満期での値 0.749494520487
# 合計値/試行回数 0.1326000035
# 各パスの満期での値 0.078131471856
# 合計値/試行回数 0.137158066573
# 各パスの満期での値 0.455806307308
# 合計値/試行回数 0.136605331705
# 各パスの満期での値 -0.0552734867718
# 合計値/試行回数 0.139265991753
# 各パスの満期での値 0.266066004835
# 合計値/試行回数 0.142636978691
# 各パスの満期での値 0.337098693761
# 合計値/試行回数 0.146001813243
# 各パスの満期での値 0.336483455218
# 合計値/試行回数 0.143181401903
# 各パスの満期での値 -0.282041133986
# 合計値/試行回数 0.147907649637
# 各パスの満期での値 0.472624773396
# 合計値/試行回数 0.150015851534
# 各パスの満期での値 0.210820189711
# 合計値/試行回数 0.157410725036
# 各パスの満期での値 0.739487350215
# 合計値/試行回数 0.156865945854
# 各パスの満期での値 -0.0544779182263
# 合計値/試行回数 0.156785893358
# 各パスの満期での値 -0.0080052496143
# 合計値/試行回数 0.155071791805
# 各パスの満期での値 -0.1714101553
# 合計値/試行回数 0.163030689189
# 各パスの満期での値 0.795889738365
# 合計値/試行回数 0.165277271539
# 各パスの満期での値 0.224658235004
# 合計値/試行回数 0.169952437235
# 各パスの満期での値 0.467516569586
# 合計値/試行回数 0.17627078393
# 各パスの満期での値 0.6318346695
# 合計値/試行回数 0.18122076665
# 各パスの満期での値 0.494998272081
# 合計値/試行回数 0.192574540605
# 各パスの満期での値 1.13537739547
# 合計値/試行回数 0.196127586015
# 各パスの満期での値 0.355304540985
# 合計値/試行回数 0.195233822728
# 各パスの満期での値 -0.089376328644
# 合計値/試行回数 0.195409244732
# 各パスの満期での値 0.0175422003597
# 合計値/試行回数 0.197674492298
# 各パスの満期での値 0.226524756627
# 合計値/試行回数 0.192679363916
# 各パスの満期での値 -0.499512838185
# 合計値/試行回数 0.195114042486
# 各パスの満期での値 0.243467856972
# 合計値/試行回数 0.194617975712
# 各パスの満期での値 -0.0496066774055
# 合計値/試行回数 0.193282843728
# 各パスの満期での値 -0.133513198446
# 合計値/試行回数 0.189779792324
# 各パスの満期での値 -0.350305140321
# 合計値/試行回数 0.196971381607
# 各パスの満期での値 0.719158928254
# 合計値/試行回数 0.202479571569
# 各パスの満期での値 0.550818996197
# 合計値/試行回数 0.197900735137
# 各パスの満期での値 -0.457883643177
# 合計値/試行回数 0.195967808796
# 各パスの満期での値 -0.193292634138
# 合計値/試行回数 0.203213861404
# 各パスの満期での値 0.724605260812
# 合計値/試行回数 0.199566585545
# 各パスの満期での値 -0.364727585847
# 合計値/試行回数 0.204138017737
# 各パスの満期での値 0.457143219145
# 合計値/試行回数 0.202155544036
# 各パスの満期での値 -0.198247370117
# 合計値/試行回数 0.201557897096
# 各パスの満期での値 -0.0597646940143
# 合計値/試行回数 0.199996514538
# 各パスの満期での値 -0.156138255807
# 合計値/試行回数 0.201756732366
# 各パスの満期での値 0.176021782849
# 合計値/試行回数 0.197234054508
# 各パスの満期での値 -0.452267785779
# 合計値/試行回数 0.196110294008
# 各パスの満期での値 -0.112376050059
# 合計値/試行回数 0.195410646288
# 各パスの満期での値 -0.0699647719184
# 合計値/試行回数 0.193648064822
# 各パスの満期での値 -0.176258146658

# %%
sum = 0
for x in [1,2,3,4]:
    sum = sum + x
sum
# Out:
# 10
